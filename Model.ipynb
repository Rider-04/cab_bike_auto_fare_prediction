# %%
# !export KAGGLE_API_TOKEN=KGAT_53bf6b119c6e348a4589c2f527e94cd6
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !mkdir -p ~/.kaggle && echo KGAT_53bf6b119c6e348a4589c2f527e94cd6 > ~/.kaggle/access_token && chmod 600 ~/.kaggle/access_token
# Out:
# The syntax of the command is incorrect.

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

# %%
api = KaggleApi()

# %%
import os
os.environ["KAGGLE_API_TOKEN"] = "KGAT_53bf6b119c6e348a4589c2f527e94cd6"

from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\lenovo\OneDrive\Desktop\Folder\cab_bike_auto_fare_prediction
# ['.git', '.gitattributes', '.gitignore', '.ipynb_checkpoints', '.kaggle', 'anaconda_projects', 'dataset', 'LICENSE', 'Merging_datasets.ipynb', 'Model.ipynb', 'README.md']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()
print("Authenticated successfully")

api.dataset_download_files('your-username/your-dataset-slug', path='./data', unzip=True)
print("Download attempted")
# Out:
# Authenticated successfully
# Dataset URL: https://www.kaggle.com/datasets/your-username/your-dataset-slug
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       3 api.authenticate()
#       4 print("Authenticated successfully")
# ----> 6 api.dataset_download_files('your-username/your-dataset-slug', path='./data', unzip=True)
#       7 print("Download attempted")
#
# File ~\anaconda3\Lib\site-packages\kaggle\api\kaggle_api_extended.py:5129, in KaggleApi.dataset_download_files(self, dataset, path, force, quiet, unzip, licenses)
#    5127     request.dataset_slug = dataset_slug
#    5128     request.dataset_version_number = int(dataset_version_number) if dataset_version_number else None
# -> 5129     response = kaggle.datasets.dataset_api_client.download_dataset(request)
#    5131 outfile = os.path.join(effective_path, dataset_slug + ".zip")
# ...

# %%
api.dataset_download_files('parthrider04/synthetic-fare-dataset', path='./data', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/parthrider04/synthetic-fare-dataset

# %%
print(api.config_values)
# Out:
# {'api_token': 'KGAT_53bf6b119c6e348a4589c2f527e94cd6', 'token': 'KGAT_53bf6b119c6e348a4589c2f527e94cd6', 'username': 'parthrider04', 'auth_method': 'ACCESS_TOKEN'}

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "parthrider04/synthetic-fare-dataset",
    "synthetic-fare-datase.csv"
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\kagglehub\exceptions.py:67, in handle_call(fn, resource_handle)
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#
# File ~\anaconda3\Lib\site-packages\kagglehub\http_resolver.py:144, in DatasetHttpResolver._resolve.<locals>.<lambda>()
#     143 os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 144 response = handle_call(lambda: api_client.datasets.dataset_api_client.download_dataset(r), h)
#     145 download_file(response, out_path, h, extract_auto_compressed_file=True)
#
# File ~\anaconda3\Lib\site-packages\kagglesdk\datasets\services\dataset_api_service.py:93, in DatasetApiClient.download_dataset(self, request)
#      91   request = ApiDownloadDatasetRequest()
# ...

# %%
import kagglehub
files = kagglehub.dataset_download("parthrider04/synthetic-fare-dataset")
print(files)

import os
print(os.listdir(files))
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 9.08M/9.08M [00:02<00:00, 3.57MB/s]
# Extracting files...
# C:\Users\lenovo\.cache\kagglehub\datasets\parthrider04\synthetic-fare-dataset\versions\1
# ['Synthetic_Fare_Dataset.csv']

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\lenovo\.cache\kagglehub\datasets\parthrider04\synthetic-fare-dataset\versions\1\Synthetic_Fare_Dataset.csv"
)

print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (392242, 21)
# ['source_dataset', 'date', 'hour', 'vehicle_type', 'pickup_location', 'drop_location', 'distance_km', 'fare_amount', 'payment_method', 'status', 'driver_rating', 'customer_rating', 'year', 'month', 'day', 'weekday', 'state', 'season', 'weather', 'phase_of_day', 'is_phase_imputed']
#   source_dataset        date  hour vehicle_type pickup_location drop_location  \
# 0  bengaluru_ola  2024-01-28   6.0         auto          Area-3        Area-2
# 1  bengaluru_ola  2024-01-17  21.0  prime sedan         Area-38       Area-26
# 2  bengaluru_ola  2024-01-30   0.0        ebike         Area-47        Area-8
# 3  bengaluru_ola  2024-01-22   8.0    prime suv         Area-11       Area-35
# 4  bengaluru_ola  2024-01-12   7.0  prime sedan         Area-43       Area-42
#
#    distance_km  fare_amount payment_method   status  ...  customer_rating  \
# 0        28.50       868.06         wallet  success  ...              4.4
# ...

# %%
# !git add .

# %%
# !git commit -m "Loaded Kaggle API"
# Out:
# [main 250718b] Loaded Kaggle API
#  2 files changed, 515 insertions(+), 71 deletions(-)

# %%
# !git push
# Out:
# To https://github.com/Rider-04/cab_bike_auto_fare_prediction.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/Rider-04/cab_bike_auto_fare_prediction.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. If you want to integrate the remote changes,
# hint: use 'git pull' before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
